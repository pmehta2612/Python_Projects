# %% [markdown]
# # IMDB Movie Dataset Analysis

# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing dataset
df = pd.read_csv(r"C:\Users\Hp Laptop\Documents\Prachi\Python Case Studies\IMDB Movie Dataset Analysis\IMDB-Movie-Data.csv")

# %%
# Viewing dataset
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# 1. Display Top 10 Rows of The Dataset
df.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
# 2. Check Last 10 Rows of The Dataset
df.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %%
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
print("Number of Rows = ",df.shape[0])
print("Number of Columns = ",df.shape[1])
# Out:
# Number of Rows =  1000
# Number of Columns =  12

# %%
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement¶
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
# 5. Check Null Values In The Dataset
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
sns.heatmap(data = df.isnull())
# Out:
# <Axes: >

# %%
# 6. Drop All The Missing Values
df.dropna(axis = 0, inplace = True)

# %%
sns.heatmap(data = df.isnull())
plt.show()

# %%
# 7. Check For Duplicate Data
print("Are there any duplicates in dataset? ",df.duplicated().any())
# Out:
# Are there any duplicates in dataset?  False

# %%
# 8. Get Overall Statistics About The DataFrame
df.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %%
# 9. Display Title of The Movie Having Runtime >= 180 Minutes
df[df['Runtime (Minutes)'] >= 180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# Name: Title, dtype: object

# %%
# 10. In Which Year There Was The Highest Voting?
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
plt.style.use('seaborn-v0_8-colorblind')
plt.figure(figsize = (12,5))
sns.barplot(x = 'Year', y = 'Votes', data = df)
plt.title("Votes by Year")
plt.show()

# %%
# 11. In Which Year There Was The Highest Revenue?
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
plt.figure(figsize = (12,4))
sns.barplot(x = 'Year', y = 'Revenue (Millions)', data = df)
plt.title("Revenue by Year")
plt.show()

# %%
# 12. Find The Average Rating For Each Director
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.groupby('Director')['Rating'].mean().sort_values(ascending = False)
# Out:
# Director
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
#                                     ...
# Sam Taylor-Johnson                  4.10
# Joey Curtis                         4.00
# George Nolfi                        3.90
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 524, dtype: float64

# %%
# 13. Display Top 10 Lengthy Movies Title
le =df.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]. \
set_index('Title')

# %%
sns.barplot(data = le, x = 'Runtime (Minutes)', y = le.index)
plt.title('Top 10 Lengthy Movies')
plt.show()

# %%
# 14. Display Number of Movies Per Year
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
plt.figure(figsize = (12,5))
sns.countplot(data = df, x = 'Year')
plt.title("Number of Movies Per Year")
plt.show()

# %%
# 15. Find Most Popular Movie Title (Higest Revenue)
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df[df['Revenue (Millions)'].max() == df['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %%
# 16. Display Top 10 Highest Rated Movie Titles And its Directors
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top_10 = df.nlargest(10,'Rating')[['Title','Director','Rating']].set_index('Title')

# %%
plt.figure(figsize = (12,6))
sns.barplot(data = top_10, x = 'Rating' , y = top_10.index)
plt.title("Top 10 Highest Rated Movie Titles")
plt.show()

# %%
# 17. Display Top 10 Highest Revenue Movie Titles
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
top_10_Revenue = df.nlargest(10,'Revenue (Millions)')[['Title','Revenue (Millions)']].set_index('Title')
top_10_Revenue
# Out:
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63
# Avatar                                                  760.51
# Jurassic World                                          652.18
# The Avengers                                            623.28
# The Dark Knight                                         533.32
# Rogue One                                               532.17
# Finding Dory                                            486.29
# Avengers: Age of Ultron                                 458.99
# The Dark Knight Rises                                   448.13
# The Hunger Games: Catching Fire                         424.65

# %%
plt.figure(figsize = (12,6))
sns.barplot(data = top_10_Revenue, x = 'Revenue (Millions)', y = top_10_Revenue.index)
plt.title("Top 10 Highest Revenue Generated Movie Titles")
plt.show()

# %%
# 18. Find Average Rating of Movies Year-wise
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data = df.groupby('Year')[['Year','Rating']].mean().sort_values(by ='Rating', ascending = False)
data
# Out:
#         Year    Rating
# Year
# 2006  2006.0  7.143902
# 2007  2007.0  7.140909
# 2011  2011.0  6.945614
# 2012  2012.0  6.933871
# 2009  2009.0  6.911111
# 2010  2010.0  6.894737
# 2013  2013.0  6.832143
# 2014  2014.0  6.822581
# 2008  2008.0  6.708333
# 2015  2015.0  6.674312
# 2016  2016.0  6.644444

# %%
plt.figure(figsize = (12,6))
sns.barplot(data = data, x = data['Year'], y = data['Rating'])
plt.title("Year Wise Average Rating")
plt.show()

# %%
# 19. Does Rating Affect The Revenue?
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
sns.scatterplot(data = df, x = 'Rating', y = 'Revenue (Millions)')
plt.title("Rating v/s Revenue")
plt.show()

# %%
# 20. Classify Movies Based on Ratings [Good,Better and Best]
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
def Rating(rating):
    if rating >= 7.0:
        return "Excellent"
    elif rating >= 6.0:
        return "Good"
    else:
        return "Average"

# %%
df["Rating_Category"] = df['Rating'].apply(Rating)

# %%
df.head(1)
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore Rating_Category
# 0     8.1  757074              333.13       76.0       Excellent

# %%
# 21. Count Number of Action Movies
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Rating_Category'],
#       dtype='object')

# %%
print("Number of Action Movies are = ",len(df[df['Genre'].str.contains('Action', case=False)]))
# Out:
# Number of Action Movies are =  277
